# %%
import os
import mne

subject_id_list = [1]

filename_raw = "files/S" 

# the code below can be put into a loop itterating on subject = range(1, 109)
"001/S001R"
epochs_list = []

metadata_list = [{
    'subject': subject_id,
    'run': run_id
} for subject_id in subject_id_list
                 for run_id in range(1,15)]


for i in range(1, 15):
# for i in [3]:
    filename_EEG = filename_raw + "%03d" % (subject,) + "/S" + "%03d" % (subject,) + "R" + "%02d" % (i,) + ".edf"
    raw_EEG_data = mne.io.read_raw_edf(filename_EEG, preload = True)

    # modified code from github
    # This step can be done before or after event extraction
    action_dict = dict()

    if i in [3, 7, 11]:
        for index, an in enumerate(raw_EEG_data.annotations.description):
            # an = annotation
            if an == "T0":
                raw_EEG_data.annotations.description[index] = "B"
            if an == "T1":
                raw_EEG_data.annotations.description[index] = "L"
            if an == "T2":
                raw_EEG_data.annotations.description[index] = "R"
            
            action_dict = dict(B=1, L=2, R=3) # this encodes the annotation for epcohs

    elif i in [4, 8, 12]:
        for index, an in enumerate(raw_EEG_data.annotations.description):
            # an = annotation
            if an == "T0":
                raw_EEG_data.annotations.description[index] = "B"
            if an == "T1":
                raw_EEG_data.annotations.description[index] = "IL"
            if an == "T2":
                raw_EEG_data.annotations.description[index] = "IR"
            
            action_dict = dict(B=1, I_L=2, I_R=3) # this encodes the annotation for epcohs
    
    elif i in [5, 9, 13]:
        for index, an in enumerate(raw_EEG_data.annotations.description):
            if an == "T0":
                raw_EEG_data.annotations.description[index] = "B"
            if an == "T1":
                raw_EEG_data.annotations.description[index] = "LR"
            if an == "T2":
                raw_EEG_data.annotations.description[index] = "F"
                print(raw_EEG_data.annotations.description[index])
            
            action_dict = dict(B=1, LR=2, F=3) # this encodes the annotation for epcohs
   
    elif i in [6, 10, 14]:
        for index, an in enumerate(raw_EEG_data.annotations.description):
            if an == "T0":
                raw_EEG_data.annotations.description[index] = "B"
            if an == "T1":
                raw_EEG_data.annotations.description[index] = "ILR"
            if an == "T2":
                raw_EEG_data.annotations.description[index] = "IF"
                print(raw_EEG_data.annotations.description[index])

            action_dict = dict(B=1, I_LR=2, I_F=3) # this encodes the annotation for epcohs

    else: 
        for index, an in enumerate(raw_EEG_data.annotations.description):
            if an == "T0":
                raw_EEG_data.annotations.description[index] = "B"

            action_dict = dict(B=1) # this encodes the annotation for epcohs

    raw_EEG_events, summary = mne.events_from_annotations(raw_EEG_data)
    
    raw_EEG_epochs = mne.Epochs(raw_EEG_data, raw_EEG_events, action_dict, tmin=-1., tmax=4.0, preload=True)
    # can use mne.Epochs(picks = Channels) to specify which channels to use
    epochs_list.append(raw_EEG_epochs)

    print(action_dict)
    # print(raw_EEG_events)
    print(raw_EEG_epochs.event_id)
    print(raw_EEG_epochs.events)
    # for i, epoch in enumerate(raw_EEG_epochs):
    #     print("epoch len:", len(epoch[0]))
    #     print("epoch:", epoch.event_id)
        # why is the length of this 801 and not 672?
# Out:
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['B']
# Not setting metadata
# 1 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1}
# {'B': 1}
# []
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['B']
# Not setting metadata
# 1 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1}
# {'B': 1}
# []
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['B', 'L', 'R']
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1, 'L': 2, 'R': 3}
# {'B': 1, 'L': 2, 'R': 3}
# [[  672     0     3]
#  [ 1328     0     1]
#  [ 2000     0     2]
#  [ 2656     0     1]
#  [ 3328     0     2]
#  [ 3984     0     1]
#  [ 4656     0     3]
#  [ 5312     0     1]
#  [ 5984     0     3]
#  [ 6640     0     1]
#  [ 7312     0     2]
#  [ 7968     0     1]
#  [ 8640     0     2]
#  [ 9296     0     1]
#  [ 9968     0     3]
#  [10624     0     1]
#  [11296     0     2]
#  [11952     0     1]
#  [12624     0     3]
#  [13280     0     1]
#  [13952     0     3]
#  [14608     0     1]
#  [15280     0     2]
#  [15936     0     1]
#  [16608     0     2]
#  [17264     0     1]
#  [17936     0     3]
#  [18592     0     1]
#  [19264     0     2]]
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['B', 'IL', 'IR']
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1, 'I_L': 2, 'I_R': 3}
# {'B': 1, 'I_L': 2, 'I_R': 3}
# [[  672     0     3]
#  [ 1328     0     1]
#  [ 2000     0     2]
#  [ 2656     0     1]
#  [ 3328     0     2]
#  [ 3984     0     1]
#  [ 4656     0     3]
#  [ 5312     0     1]
#  [ 5984     0     3]
#  [ 6640     0     1]
#  [ 7312     0     2]
#  [ 7968     0     1]
#  [ 8640     0     3]
#  [ 9296     0     1]
#  [ 9968     0     2]
#  [10624     0     1]
#  [11296     0     3]
#  [11952     0     1]
#  [12624     0     2]
#  [13280     0     1]
#  [13952     0     2]
#  [14608     0     1]
#  [15280     0     3]
#  [15936     0     1]
#  [16608     0     2]
#  [17264     0     1]
#  [17936     0     3]
#  [18592     0     1]
#  [19264     0     2]]
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# F
# F
# F
# F
# F
# F
# F
# Used Annotations descriptions: ['B', 'F', 'LR']
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1, 'LR': 2, 'F': 3}
# {'B': 1, 'LR': 2, 'F': 3}
# [[  672     0     2]
#  [ 1328     0     1]
#  [ 2000     0     3]
#  [ 2656     0     1]
#  [ 3328     0     2]
#  [ 3984     0     1]
#  [ 4656     0     3]
#  [ 5312     0     1]
#  [ 5984     0     2]
#  [ 6640     0     1]
#  [ 7312     0     3]
#  [ 7968     0     1]
#  [ 8640     0     3]
#  [ 9296     0     1]
#  [ 9968     0     2]
#  [10624     0     1]
#  [11296     0     2]
#  [11952     0     1]
#  [12624     0     3]
#  [13280     0     1]
#  [13952     0     2]
#  [14608     0     1]
#  [15280     0     3]
#  [15936     0     1]
#  [16608     0     3]
#  [17264     0     1]
#  [17936     0     2]
#  [18592     0     1]
#  [19264     0     3]]
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# IF
# IF
# IF
# IF
# IF
# IF
# IF
# IF
# Used Annotations descriptions: ['B', 'IF', 'IL']
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1, 'I_LR': 2, 'I_F': 3}
# {'B': 1, 'I_LR': 2, 'I_F': 3}
# [[  672     0     2]
#  [ 1328     0     1]
#  [ 2000     0     3]
#  [ 2656     0     1]
#  [ 3328     0     3]
#  [ 3984     0     1]
#  [ 4656     0     2]
#  [ 5312     0     1]
#  [ 5984     0     3]
#  [ 6640     0     1]
#  [ 7312     0     2]
#  [ 7968     0     1]
#  [ 8640     0     2]
#  [ 9296     0     1]
#  [ 9968     0     3]
#  [10624     0     1]
#  [11296     0     3]
#  [11952     0     1]
#  [12624     0     2]
#  [13280     0     1]
#  [13952     0     2]
#  [14608     0     1]
#  [15280     0     3]
#  [15936     0     1]
#  [16608     0     3]
#  [17264     0     1]
#  [17936     0     2]
#  [18592     0     1]
#  [19264     0     2]]
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['B', 'L', 'R']
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1, 'L': 2, 'R': 3}
# {'B': 1, 'L': 2, 'R': 3}
# [[  672     0     2]
#  [ 1328     0     1]
#  [ 2000     0     3]
#  [ 2656     0     1]
#  [ 3328     0     2]
#  [ 3984     0     1]
#  [ 4656     0     3]
#  [ 5312     0     1]
#  [ 5984     0     2]
#  [ 6640     0     1]
#  [ 7312     0     3]
#  [ 7968     0     1]
#  [ 8640     0     3]
#  [ 9296     0     1]
#  [ 9968     0     2]
#  [10624     0     1]
#  [11296     0     2]
#  [11952     0     1]
#  [12624     0     3]
#  [13280     0     1]
#  [13952     0     3]
#  [14608     0     1]
#  [15280     0     2]
#  [15936     0     1]
#  [16608     0     3]
#  [17264     0     1]
#  [17936     0     2]
#  [18592     0     1]
#  [19264     0     2]]
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['B', 'IL', 'IR']
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1, 'I_L': 2, 'I_R': 3}
# {'B': 1, 'I_L': 2, 'I_R': 3}
# [[  672     0     2]
#  [ 1328     0     1]
#  [ 2000     0     3]
#  [ 2656     0     1]
#  [ 3328     0     2]
#  [ 3984     0     1]
#  [ 4656     0     3]
#  [ 5312     0     1]
#  [ 5984     0     2]
#  [ 6640     0     1]
#  [ 7312     0     3]
#  [ 7968     0     1]
#  [ 8640     0     2]
#  [ 9296     0     1]
#  [ 9968     0     3]
#  [10624     0     1]
#  [11296     0     3]
#  [11952     0     1]
#  [12624     0     2]
#  [13280     0     1]
#  [13952     0     2]
#  [14608     0     1]
#  [15280     0     3]
#  [15936     0     1]
#  [16608     0     3]
#  [17264     0     1]
#  [17936     0     2]
#  [18592     0     1]
#  [19264     0     2]]
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# F
# F
# F
# F
# F
# F
# F
# Used Annotations descriptions: ['B', 'F', 'LR']
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1, 'LR': 2, 'F': 3}
# {'B': 1, 'LR': 2, 'F': 3}
# [[  672     0     3]
#  [ 1328     0     1]
#  [ 2000     0     2]
#  [ 2656     0     1]
#  [ 3328     0     3]
#  [ 3984     0     1]
#  [ 4656     0     2]
#  [ 5312     0     1]
#  [ 5984     0     2]
#  [ 6640     0     1]
#  [ 7312     0     3]
#  [ 7968     0     1]
#  [ 8640     0     3]
#  [ 9296     0     1]
#  [ 9968     0     2]
#  [10624     0     1]
#  [11296     0     3]
#  [11952     0     1]
#  [12624     0     2]
#  [13280     0     1]
#  [13952     0     3]
#  [14608     0     1]
#  [15280     0     2]
#  [15936     0     1]
#  [16608     0     2]
#  [17264     0     1]
#  [17936     0     3]
#  [18592     0     1]
#  [19264     0     3]]
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# IF
# IF
# IF
# IF
# IF
# IF
# IF
# IF
# Used Annotations descriptions: ['B', 'IF', 'IL']
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1, 'I_LR': 2, 'I_F': 3}
# {'B': 1, 'I_LR': 2, 'I_F': 3}
# [[  672     0     3]
#  [ 1328     0     1]
#  [ 2000     0     2]
#  [ 2656     0     1]
#  [ 3328     0     2]
#  [ 3984     0     1]
#  [ 4656     0     3]
#  [ 5312     0     1]
#  [ 5984     0     2]
#  [ 6640     0     1]
#  [ 7312     0     3]
#  [ 7968     0     1]
#  [ 8640     0     3]
#  [ 9296     0     1]
#  [ 9968     0     2]
#  [10624     0     1]
#  [11296     0     2]
#  [11952     0     1]
#  [12624     0     3]
#  [13280     0     1]
#  [13952     0     3]
#  [14608     0     1]
#  [15280     0     2]
#  [15936     0     1]
#  [16608     0     2]
#  [17264     0     1]
#  [17936     0     3]
#  [18592     0     1]
#  [19264     0     2]]
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['B', 'L', 'R']
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1, 'L': 2, 'R': 3}
# {'B': 1, 'L': 2, 'R': 3}
# [[  672     0     2]
#  [ 1328     0     1]
#  [ 2000     0     3]
#  [ 2656     0     1]
#  [ 3328     0     3]
#  [ 3984     0     1]
#  [ 4656     0     2]
#  [ 5312     0     1]
#  [ 5984     0     3]
#  [ 6640     0     1]
#  [ 7312     0     2]
#  [ 7968     0     1]
#  [ 8640     0     2]
#  [ 9296     0     1]
#  [ 9968     0     3]
#  [10624     0     1]
#  [11296     0     3]
#  [11952     0     1]
#  [12624     0     2]
#  [13280     0     1]
#  [13952     0     2]
#  [14608     0     1]
#  [15280     0     3]
#  [15936     0     1]
#  [16608     0     3]
#  [17264     0     1]
#  [17936     0     2]
#  [18592     0     1]
#  [19264     0     3]]
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['B', 'IL', 'IR']
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1, 'I_L': 2, 'I_R': 3}
# {'B': 1, 'I_L': 2, 'I_R': 3}
# [[  672     0     3]
#  [ 1328     0     1]
#  [ 2000     0     2]
#  [ 2656     0     1]
#  [ 3328     0     3]
#  [ 3984     0     1]
#  [ 4656     0     2]
#  [ 5312     0     1]
#  [ 5984     0     2]
#  [ 6640     0     1]
#  [ 7312     0     3]
#  [ 7968     0     1]
#  [ 8640     0     3]
#  [ 9296     0     1]
#  [ 9968     0     2]
#  [10624     0     1]
#  [11296     0     2]
#  [11952     0     1]
#  [12624     0     3]
#  [13280     0     1]
#  [13952     0     3]
#  [14608     0     1]
#  [15280     0     2]
#  [15936     0     1]
#  [16608     0     3]
#  [17264     0     1]
#  [17936     0     2]
#  [18592     0     1]
#  [19264     0     3]]
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# F
# F
# F
# F
# F
# F
# F
# F
# Used Annotations descriptions: ['B', 'F', 'LR']
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1, 'LR': 2, 'F': 3}
# {'B': 1, 'LR': 2, 'F': 3}
# [[  672     0     3]
#  [ 1328     0     1]
#  [ 2000     0     2]
#  [ 2656     0     1]
#  [ 3328     0     3]
#  [ 3984     0     1]
#  [ 4656     0     2]
#  [ 5312     0     1]
#  [ 5984     0     2]
#  [ 6640     0     1]
#  [ 7312     0     3]
#  [ 7968     0     1]
#  [ 8640     0     2]
#  [ 9296     0     1]
#  [ 9968     0     3]
#  [10624     0     1]
#  [11296     0     3]
#  [11952     0     1]
#  [12624     0     2]
#  [13280     0     1]
#  [13952     0     3]
#  [14608     0     1]
#  [15280     0     2]
#  [15936     0     1]
#  [16608     0     2]
#  [17264     0     1]
#  [17936     0     3]
#  [18592     0     1]
#  [19264     0     2]]
# Extracting EDF parameters from /Users/jakesolsky/Documents/GitHub/EEG-AI-Control-System/files/S001/S001R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# IF
# IF
# IF
# IF
# IF
# IF
# IF
# IF
# Used Annotations descriptions: ['B', 'IF', 'IL']
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-1.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 801 original time points ...
# 1 bad epochs dropped
# {'B': 1, 'I_LR': 2, 'I_F': 3}
# {'B': 1, 'I_LR': 2, 'I_F': 3}
# [[  672     0     2]
#  [ 1328     0     1]
#  [ 2000     0     3]
#  [ 2656     0     1]
#  [ 3328     0     2]
#  [ 3984     0     1]
#  [ 4656     0     3]
#  [ 5312     0     1]
#  [ 5984     0     3]
#  [ 6640     0     1]
#  [ 7312     0     2]
#  [ 7968     0     1]
#  [ 8640     0     3]
#  [ 9296     0     1]
#  [ 9968     0     2]
#  [10624     0     1]
#  [11296     0     3]
#  [11952     0     1]
#  [12624     0     2]
#  [13280     0     1]
#  [13952     0     2]
#  [14608     0     1]
#  [15280     0     3]
#  [15936     0     1]
#  [16608     0     2]
#  [17264     0     1]
#  [17936     0     3]
#  [18592     0     1]
#  [19264     0     2]]

# %%
# T0 = B indicates baseline

# TASK 1 (open and close left or right fist)
# if run in [3, 7, 11]
# T1 = L indicates motor opening and closing left fist;
# T2 = R indicates motor opening and closing right fist;

# TASK 2 (imagine opening and closing left or right fist)
# if run in [4, 8, 12]
# T1 = I_L indicates motor imagination of opening and closing left fist;
# T2 = I_R indicates motor imagination of opening and closing right fist;

# TASK 3 (open and close both fists or both feet)
# if run in [5, 9, 13]
# T1 = LR indicates motor imagination of opening and closing both fists;
# T2 = F indicates motor imagination of opening and closing both feet. 

# TASK 4 (imagine opening and closing both fists or both feet)
# if run in [6, 10, 14]
# T1 = I_LR indicates motor imagination of opening and closing both fists;
# T2 = I_F indicates motor imagination of opening and closing both feet

# %%
# %pip install torcheeg
# import torcheeg
from torcheeg.datasets import MNEDataset

dataset = MNEDataset(epochs_list = epochs_list, metadata_list = metadata_list)
# Out:
# [MNE]:  21%|██▏       | 3/14 [00:00<00:00, 23.03it/s]
# The current io_size is not enough, and double the LMDB map size to 20971520 automatically.
# The current io_size is not enough, and double the LMDB map size to 41943040 automatically.
# [MNE]:  43%|████▎     | 6/14 [00:00<00:00, 13.69it/s]
# The current io_size is not enough, and double the LMDB map size to 83886080 automatically.
# [MNE]:  71%|███████▏  | 10/14 [00:00<00:00, 11.29it/s]
# The current io_size is not enough, and double the LMDB map size to 167772160 automatically.
# [MNE]: 100%|██████████| 14/14 [00:01<00:00, 12.20it/s]
# Please wait for the writing process to complete...

# %%
epochs_list
# Out:
# [<Epochs |  0 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~65 kB, data loaded,
#   'B': 0>,
#  <Epochs |  0 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~65 kB, data loaded,
#   'B': 0>,
#  <Epochs |  29 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~11.4 MB, data loaded,
#   'B': 14
#   'L': 8
#   'R': 7>,
#  <Epochs |  29 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~11.4 MB, data loaded,
#   'B': 14
#   'I_L': 8
#   'I_R': 7>,
#  <Epochs |  29 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~11.4 MB, data loaded,
#   'B': 14
#   'LR': 7
#   'F': 8>,
#  <Epochs |  29 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~11.4 MB, data loaded,
#   'B': 14
#   'I_LR': 8
#   'I_F': 7>,
#  <Epochs |  29 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~11.4 MB, data loaded,
#   'B': 14
#   'L': 8
#   'R': 7>,
#  <Epochs |  29 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~11.4 MB, data loaded,
#   'B': 14
#   'I_L': 8
#   'I_R': 7>,
#  <Epochs |  29 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~11.4 MB, data loaded,
#   'B': 14
#   'LR': 7
#   'F': 8>,
#  <Epochs |  29 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~11.4 MB, data loaded,
#   'B': 14
#   'I_LR': 8
#   'I_F': 7>,
#  <Epochs |  29 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~11.4 MB, data loaded,
#   'B': 14
#   'L': 7
#   'R': 8>,
#  <Epochs |  29 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~11.4 MB, data loaded,
#   'B': 14
#   'I_L': 7
#   'I_R': 8>,
#  <Epochs |  29 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~11.4 MB, data loaded,
#   'B': 14
#   'LR': 8
#   'F': 7>,
#  <Epochs |  29 events (all good), -1 - 4 sec, baseline -1 – 0 sec, ~11.4 MB, data loaded,
#   'B': 14
#   'I_LR': 8
#   'I_F': 7>]

# %%
print(metadata_list)
# Out:
# [[{'subject': 1, 'run': 1}], [{'subject': 1, 'run': 2}], [{'subject': 1, 'run': 3}], [{'subject': 1, 'run': 4}], [{'subject': 1, 'run': 5}], [{'subject': 1, 'run': 6}], [{'subject': 1, 'run': 7}], [{'subject': 1, 'run': 8}], [{'subject': 1, 'run': 9}], [{'subject': 1, 'run': 10}], [{'subject': 1, 'run': 11}], [{'subject': 1, 'run': 12}], [{'subject': 1, 'run': 13}], [{'subject': 1, 'run': 14}]]
