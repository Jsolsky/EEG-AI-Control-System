# %%
import logging
import os
import random
import time

import mne
import numpy as np
import torch
from torch.utils.data.dataloader import DataLoader
from torcheeg import transforms
from torcheeg.datasets import MNEDataset
from torcheeg.models import TSCeption
from torcheeg.trainers import ClassificationTrainer
import Raw_EEG_processing

# %%
dataset = Raw_EEG_processing.load_data(subject_id_list=list(range(1,10)))
# Out:
# The target folder already exists, if you need to regenerate the database IO, please delete the path ./io/mne.

# %%
os.makedirs('./tmp_out/examples_mne_dataset/log', exist_ok=True)
logger = logging.getLogger('Examples of MNEDataset')
logger.setLevel(logging.DEBUG)
console_handler = logging.StreamHandler()
timeticks = time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime())
file_handler = logging.FileHandler(
    os.path.join('./tmp_out/examples_mne_dataset/log', f'{timeticks}.log'))
logger.addHandler(console_handler)
logger.addHandler(file_handler)

# %%
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


seed_everything(42)

# %%
class MyClassificationTrainer(ClassificationTrainer):
    def log(self, *args, **kwargs):
        if self.is_main:
            logger.info(*args, **kwargs)

# %%
metadata_list
# Out:
# [{'subject': 1, 'run': 6},
#  {'subject': 1, 'run': 10},
#  {'subject': 1, 'run': 14},
#  {'subject': 2, 'run': 6},
#  {'subject': 2, 'run': 10},
#  {'subject': 2, 'run': 14},
#  {'subject': 3, 'run': 6},
#  {'subject': 3, 'run': 10},
#  {'subject': 3, 'run': 14},
#  {'subject': 4, 'run': 6},
#  {'subject': 4, 'run': 10},
#  {'subject': 4, 'run': 14},
#  {'subject': 5, 'run': 6},
#  {'subject': 5, 'run': 10},
#  {'subject': 5, 'run': 14},
#  {'subject': 6, 'run': 6},
#  {'subject': 6, 'run': 10},
#  {'subject': 6, 'run': 14},
#  {'subject': 7, 'run': 6},
#  {'subject': 7, 'run': 10},
#  {'subject': 7, 'run': 14},
#  {'subject': 8, 'run': 6},
#  {'subject': 8, 'run': 10},
#  {'subject': 8, 'run': 14},
#  {'subject': 9, 'run': 6},
#  {'subject': 9, 'run': 10},
#  {'subject': 9, 'run': 14},
#  {'subject': 10, 'run': 6},
#  {'subject': 10, 'run': 10},
#  {'subject': 10, 'run': 14},
#  {'subject': 11, 'run': 6},
#  {'subject': 11, 'run': 10},
#  {'subject': 11, 'run': 14},
#  {'subject': 12, 'run': 6},
#  {'subject': 12, 'run': 10},
#  {'subject': 12, 'run': 14},
#  {'subject': 13, 'run': 6},
#  {'subject': 13, 'run': 10},
#  {'subject': 13, 'run': 14},
#  {'subject': 14, 'run': 6},
#  {'subject': 14, 'run': 10},
#  {'subject': 14, 'run': 14},
#  {'subject': 15, 'run': 6},
#  {'subject': 15, 'run': 10},
#  {'subject': 15, 'run': 14},
#  {'subject': 16, 'run': 6},
#  {'subject': 16, 'run': 10},
#  {'subject': 16, 'run': 14},
#  {'subject': 17, 'run': 6},
#  {'subject': 17, 'run': 10},
#  {'subject': 17, 'run': 14},
#  {'subject': 18, 'run': 6},
#  {'subject': 18, 'run': 10},
#  {'subject': 18, 'run': 14},
#  {'subject': 19, 'run': 6},
#  {'subject': 19, 'run': 10},
#  {'subject': 19, 'run': 14},
#  {'subject': 20, 'run': 6},
#  {'subject': 20, 'run': 10},
#  {'subject': 20, 'run': 14},
#  {'subject': 21, 'run': 6},
#  {'subject': 21, 'run': 10},
#  {'subject': 21, 'run': 14}]

# %%
filename_raw = "files/S" 

metadata_list = [{
    'subject': subject_id,
    'run': run_id
} for subject_id in range(1, 22)
                 for run_id in [6, 10, 14]]  # motor imagery: hands vs feet

epochs_list = []
for metadata in metadata_list:
    subject_id = metadata['subject']
    run = metadata['run']
    
    filename_EEG = filename_raw + "%03d" % (subject_id,) + "/S" + "%03d" % (subject_id,) + "R" + "%02d" % (run,) + ".edf"
    # physionet_path = mne.datasets.eegbci.load_data(metadata['subject'],
    #                                                metadata['run'],
    #                                                update_path=False)[0]
    
    raw = mne.io.read_raw_edf(filename_EEG, preload=True, stim_channel='auto')
    mne.datasets.eegbci.standardize(raw)

    montage = mne.channels.make_standard_montage('standard_1005')
    raw.set_montage(montage)

    raw.filter(7., 30., fir_design='firwin', skip_by_annotation='edge')
    events, _ = mne.events_from_annotations(raw, event_id=dict(T1=2, T2=3))
    picks = mne.pick_types(raw.info,
                           meg=False,
                           eeg=True,
                           stim=False,
                           eog=False,
                           exclude='bads')
    # init Epochs with raw EEG signals and corresponding event annotations. Here, tmin is set to -1., and tmax is set to 4.0, to avoid classification of evoked responses by using epochs that start 1s after cue onset.
    epochs_list.append(
        mne.Epochs(raw,
                   events,
                   dict(hands=2, feet=3),
                   tmin=-1.,
                   tmax=4.0,
                   proj=True,
                   picks=picks))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 11
#       9 epochs_list = []
#      10 for metadata in metadata_list:
# ---> 11     filename_EEG = filename_raw + "%03d" % (subject_id,) + "/S" + "%03d" % (subject_id,) + "R" + "%02d" % (i,) + ".edf"
#      12     # physionet_path = mne.datasets.eegbci.load_data(metadata['subject'],
#      13     #                                                metadata['run'],
#      14     #                                                update_path=False)[0]
#      16     raw = mne.io.read_raw_edf(filename_EEG, preload=True, stim_channel='auto')
#
# NameError: name 'subject_id' is not defined

# %%
dataset = MNEDataset(epochs_list=epochs_list,
                     metadata_list=metadata_list,
                     chunk_size=160,
                     overlap=80,
                     io_path='./tmp_out/examples_mne_dataset/physionet',
                     offline_transform=transforms.Compose(
                         [transforms.MeanStdNormalize(),
                          transforms.To2d()]),
                     online_transform=transforms.ToTensor(),
                     label_transform=transforms.Compose([
                         transforms.Select('event'),
                         transforms.Lambda(lambda x: x - 2)
                     ]),
                     num_worker=2)
# Out:
# "dataset = MNEDataset(epochs_list=epochs_list,\n                     metadata_list=metadata_list,\n                     chunk_size=160,\n                     overlap=80,\n                     io_path='./tmp_out/examples_mne_dataset/physionet',\n                     offline_transform=transforms.Compose(\n                         [transforms.MeanStdNormalize(),\n                          transforms.To2d()]),\n                     online_transform=transforms.ToTensor(),\n                     label_transform=transforms.Compose([\n                         transforms.Select('event'),\n                         transforms.Lambda(lambda x: x - 2)\n                     ]),\n                     num_worker=2)"

# %%
if __name__ == "__main__":
    dataset = MNEDataset(epochs_list=epochs_list,
                  metadata_list=metadata_list,
                  chunk_size=160,
                  overlap=80,
                  io_path='./tmp_out/examples_mne_dataset/physionet',
                  offline_transform=transforms.Compose(
                      [transforms.MeanStdNormalize(),
                       transforms.To2d()]),
                  online_transform=transforms.ToTensor(),
                  label_transform=transforms.Compose([
                      transforms.Select('event'),
                      transforms.Lambda(lambda x: x - 2)
                  ]),
                  io_mode='pickle',
                  num_worker=2)
# Out:
# 'if __name__ == "__main__":\n    dataset = MNEDataset(epochs_list=epochs_list,\n                  metadata_list=metadata_list,\n                  chunk_size=160,\n                  overlap=80,\n                  io_path=\'./tmp_out/examples_mne_dataset/physionet\',\n                  offline_transform=transforms.Compose(\n                      [transforms.MeanStdNormalize(),\n                       transforms.To2d()]),\n                  online_transform=transforms.ToTensor(),\n                  label_transform=transforms.Compose([\n                      transforms.Select(\'event\'),\n                      transforms.Lambda(lambda x: x - 2)\n                  ]),\n                  io_mode=\'pickle\',\n                  num_worker=2)'

# %%
#input individual subject in data import at the top (0-108)

#This is outer mne dataset object
#print(dataset)
#This is Trial (0-347 (?))
#print(dataset[1])
#This is the sensor channel [0-347][0][0-63]
#print(len(dataset[0][0][0]))
#print('\n\n')
#This is the individual trial's metadata [0-347][1]
#print(dataset[0][1])
#This is the time series [0-348][0][0-800]
#print(len(dataset[0][0][0]))
#print(dataset[0][0][1])
#print(dataset[0][0][2])
#print(dataset[0][1])
#print(dataset[1][0])
#print(dataset[108][1])
# Out:
# MNEDataset(
#     io_path='./io/mne',
#     io_size=10485760,
#     io_mode='lmdb',
#     in_memory=False,
#     chunk_size=-1,
#     overlap=0,
#     num_channel=-1,
#     online_transform=None,
#     offline_transform=None,
#     label_transform=None,
#     before_trial=None,
#     after_trial=None,
#     num_worker=1,
#     verbose=True
# )
# length=348
# (array([[-2.79068323e-05, -3.49068323e-05, -5.49068323e-05, ...,
#         -1.99068323e-05, -2.59068323e-05, -1.79068323e-05],
#        [-2.97515528e-05, -3.57515528e-05, -5.47515528e-05, ...,
#         -1.07515528e-05, -1.57515528e-05, -1.27515528e-05],
#        [-3.05465839e-05, -3.25465839e-05, -5.65465839e-05, ...,
#         -1.55465839e-05, -1.25465839e-05, -7.54658385e-06],
#        ...,
#        [ 3.03726708e-05,  3.43726708e-05,  1.83726708e-05, ...,
#          1.83726708e-05,  3.03726708e-05,  4.53726708e-05],
#        [ 4.19316770e-05,  4.69316770e-05,  2.49316770e-05, ...,
#          6.93167702e-06,  1.89316770e-05,  3.79316770e-05],
#        [ 7.92608696e-05,  5.72608696e-05,  1.62608696e-05, ...,
#         -6.73913043e-06,  1.42608696e-05,  3.62608696e-05]]), {'trial_id': 1, 'start_at': 1328, 'end_at': 2129, 'event': 1, 'clip_id': '2_1', 'subject': 1, 'run': 3})
# 801
#
#
#
# {'trial_id': 0, 'start_at': 672, 'end_at': 1473, 'event': 3, 'clip_id': '2_0', 'subject': 1, 'run': 3}
# 801
# [ 1.54037267e-05  3.40372671e-06  9.40372671e-06  2.14037267e-05
#   2.04037267e-05  7.40372671e-06 -6.59627329e-06  4.40372671e-06
#   4.03726708e-07 -1.59627329e-06 -8.59627329e-06 -3.05962733e-05
#  -1.25962733e-05 -1.59627329e-06  4.03726708e-07  1.34037267e-05
# {'trial_id': 0, 'start_at': 672, 'end_at': 1473, 'event': 3, 'clip_id': '2_0', 'subject': 1, 'run': 3}
# [[-2.79068323e-05 -3.49068323e-05 -5.49068323e-05 ... -1.99068323e-05
#   -2.59068323e-05 -1.79068323e-05]
#  [-2.97515528e-05 -3.57515528e-05 -5.47515528e-05 ... -1.07515528e-05
#   -1.57515528e-05 -1.27515528e-05]
#  [-3.05465839e-05 -3.25465839e-05 -5.65465839e-05 ... -1.55465839e-05
#   -1.25465839e-05 -7.54658385e-06]
#  ...
#  [ 3.03726708e-05  3.43726708e-05  1.83726708e-05 ...  1.83726708e-05
#    3.03726708e-05  4.53726708e-05]
#  [ 4.19316770e-05  4.69316770e-05  2.49316770e-05 ...  6.93167702e-06
#    1.89316770e-05  3.79316770e-05]
#  [ 7.92608696e-05  5.72608696e-05  1.62608696e-05 ... -6.73913043e-06
#    1.42608696e-05  3.62608696e-05]]
# {'trial_id': 21, 'start_at': 14608, 'end_at': 15409, 'event': 1, 'clip_id': '5_21', 'subject': 1, 'run': 6}

# %%
from torcheeg.model_selection import KFold

k_folds = KFold(n_splits=5,
                split_path=f'./tmp_out/split',)

# %%
print(k_folds)
# Out:
# KFold(n_splits=5, shuffle=False, random_state=None, split_path='./tmp_out/split')

# %%
#from IPython.core.debugger import set_trace
print(dataset)
print('hi')
#model.to('cpu')
for i, (train_dataset, val_dataset) in enumerate(k_folds.split(dataset)):
    #set_trace()
    print(i, (train_dataset, val_dataset))
    # Initialize the model
    model = TSCeption(num_electrodes=64,
                      num_classes=2,
                      num_T=15,
                      num_S=15,
                      in_channels=1,
                      hid_channels=32,
                      sampling_rate=160,
                      dropout=0.5)

    # Initialize the trainer and use the 0-th GPU for training, or set device_ids=[] to use CPU
    trainer = MyClassificationTrainer(model=model,
                                      lr=1e-4,
                                      weight_decay=1e-4,
                                      device_ids=[])

    # Initialize several batches of training samples and test samples
    train_loader = DataLoader(train_dataset,
                              batch_size=256,
                              shuffle=True,
                              num_workers=4)
    val_loader = DataLoader(val_dataset,
                            batch_size=256,
                            shuffle=False,
                            num_workers=4)
    print('test')
    print('/n')
    print(train_dataset)
    print(train_loader)
    print(val_dataset)
    print(val_loader)

    # Do 50 rounds of training
    trainer.fit(train_loader, val_loader, num_epochs=50)
    trainer.test(val_loader)
    trainer.save_state_dict(f'./tmp_out/examples_mne_dataset/weight/{i}.pth')
# Out:
# Epoch 1
# -------------------------------
# MNEDataset(
#     io_path='./io/mne',
#     io_size=10485760,
#     io_mode='lmdb',
#     in_memory=False,
#     chunk_size=-1,
#     overlap=0,
#     num_channel=-1,
#     online_transform=None,
#     offline_transform=None,
#     label_transform=None,
#     before_trial=None,
#     after_trial=None,
#     num_worker=1,
#     verbose=True
# )
# length=348
# hi
# 0 (MNEDataset(
#     io_path='./io/mne',
#     io_size=10485760,
#     io_mode='lmdb',
#     in_memory=False,
#     chunk_size=-1,
#     overlap=0,
#     num_channel=-1,
#     online_transform=None,
#     offline_transform=None,
#     label_transform=None,
#     before_trial=None,
#     after_trial=None,
#     num_worker=1,
#     verbose=True
# )
# length=278, MNEDataset(
#     io_path='./io/mne',
#     io_size=10485760,
#     io_mode='lmdb',
#     in_memory=False,
#     chunk_size=-1,
#     overlap=0,
#     num_channel=-1,
#     online_transform=None,
#     offline_transform=None,
#     label_transform=None,
#     before_trial=None,
#     after_trial=None,
#     num_worker=1,
#     verbose=True
# )
# length=70)
# test
# /n
# MNEDataset(
#     io_path='./io/mne',
#     io_size=10485760,
#     io_mode='lmdb',
#     in_memory=False,
#     chunk_size=-1,
#     overlap=0,
#     num_channel=-1,
#     online_transform=None,
#     offline_transform=None,
#     label_transform=None,
#     before_trial=None,
#     after_trial=None,
#     num_worker=1,
#     verbose=True
# )
# length=278
# <torch.utils.data.dataloader.DataLoader object at 0x0000020A0025A750>
# MNEDataset(
#     io_path='./io/mne',
#     io_size=10485760,
#     io_mode='lmdb',
#     in_memory=False,
#     chunk_size=-1,
#     overlap=0,
#     num_channel=-1,
#     online_transform=None,
#     offline_transform=None,
#     label_transform=None,
#     before_trial=None,
#     after_trial=None,
#     num_worker=1,
#     verbose=True
# )
# length=70
# <torch.utils.data.dataloader.DataLoader object at 0x0000020A51564E10>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 41
#      38 print(val_loader)
#      40 # Do 50 rounds of training
# ---> 41 trainer.fit(train_loader, val_loader, num_epochs=50)
#      42 trainer.test(val_loader)
#      43 trainer.save_state_dict(f'./tmp_out/examples_mne_dataset/weight/{i}.pth')
#
# File c:\Users\ingra\AppData\Local\Programs\Python\Python311\Lib\site-packages\torcheeg\trainers\classification_trainer.py:223, in ClassificationTrainer.fit(self, train_loader, val_loader, num_epochs, **kwargs)
#     212 def fit(self,
#     213         train_loader: DataLoader,
#     214         val_loader: DataLoader,
#     215         num_epochs: int = 1,
#     216         **kwargs):
#     217     r'''
#     218     Args:
#     219         train_loader (DataLoader): Iterable DataLoader for traversing the training data batch (torch.utils.data.dataloader.DataLoader, torch_geometric.loader.DataLoader, etc).
#     220         val_loader (DataLoader): Iterable DataLoader for traversing the validation data batch (torch.utils.data.dataloader.DataLoader, torch_geometric.loader.DataLoader, etc).
#     221         num_epochs (int): training epochs. (defualt: :obj:`1`)
#     222     '''
# --> 223     super().fit(train_loader=train_loader,
#     224                 val_loader=val_loader,
#     225                 num_epochs=num_epochs,
#     226                 **kwargs)
#
# File c:\Users\ingra\AppData\Local\Programs\Python\Python311\Lib\site-packages\torcheeg\trainers\basic_trainer.py:258, in BasicTrainer.fit(self, train_loader, val_loader, num_epochs, **kwargs)
#     256 self.before_training_step(batch_id, num_batches, **kwargs)
#     257 # hook
# --> 258 self.on_training_step(train_batch, batch_id, num_batches,
#     259                       **kwargs)
#     260 # hook
#     261 self.after_training_step(batch_id, num_batches, **kwargs)
#
# File c:\Users\ingra\AppData\Local\Programs\Python\Python311\Lib\site-packages\torcheeg\trainers\classification_trainer.py:140, in ClassificationTrainer.on_training_step(self, train_batch, batch_id, num_batches, **kwargs)
#     137 self.train_loss.reset()
#     139 X = train_batch[0].to(self.device)
# --> 140 y = train_batch[1].to(self.device)
#     142 # compute prediction error
#     143 pred = self.modules['model'](X)
#
# AttributeError: 'dict' object has no attribute 'to'
